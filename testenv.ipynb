# %%
import json
import gzip
import random

# %%
# input_file = "datasets/All_Beauty.jsonl.gz"

# train_file = open("datasets/reviews_train.jsonl", "w")
# val_file = open("datasets/reviews_val.jsonl", "w")
# test_file = open("datasets/reviews_test.jsonl", "w")

# asin_to_split = {}

# with gzip.open(input_file, "rt", encoding="utf-8") as fp:
#     for line in fp:
#         line = line.strip()
#         if not line:
#             continue

#         review = json.loads(line)

#         # 80 / 10 / 10 SPLIT
#         r = random.random()
#         if r < 0.8:
#             split = "train"
#             train_file.write(line + "\n")
#         elif r < 0.9:
#             split = "val"
#             val_file.write(line + "\n")
#         else:
#             split = "test"
#             test_file.write(line + "\n")

# train_file.close()
# val_file.close()
# test_file.close()

# %%
# metadata_file = "datasets/meta_All_Beauty.jsonl.gz"
# output_file = "datasets/meta_one_line.jsonl"

# with gzip.open(metadata_file, "rt", encoding="utf-8") as fp, open(output_file, "w", encoding="utf-8") as out_fp:
#     for line in fp:
#         line = line.strip()
#         if not line:
#             continue
#         entry = json.loads(line)
#         out_fp.write(json.dumps(entry) + "\n")

# %%
with open("datasets/reviews_train.jsonl", "r") as fp:
    for i, line in enumerate(fp):
        entry = json.loads(line)
        print(json.dumps(entry, indent=2))
        if i == 5:
            break
# Out:
# {
#   "rating": 5.0,
#   "title": "Such a lovely scent but not overpowering.",
#   "text": "This spray is really nice. It smells really good, goes on really fine, and does the trick. I will say it feels like you need a lot of it though to get the texture I want. I have a lot of hair, medium thickness. I am comparing to other brands with yucky chemicals so I'm gonna stick with this. Try it!",
#   "images": [],
#   "asin": "B00YQ6X8EO",
#   "parent_asin": "B00YQ6X8EO",
#   "user_id": "AGKHLEW2SOWHNMFQIJGBECAF7INQ",
#   "timestamp": 1588687728923,
#   "helpful_vote": 0,
#   "verified_purchase": true
# }
# {
#   "rating": 4.0,
#   "title": "Works great but smells a little weird.",
#   "text": "This product does what I need it to do, I just wish it was odorless or had a soft coconut smell. Having my head smell like an orange coffee is offputting. (granted, I did know the smell was described but I was hoping it would be light)",
#   "images": [],
#   "asin": "B081TJ8YS3",
# ...

# %%
with open("datasets/meta.jsonl", "r") as fp:
    for i, line in enumerate(fp):
        entry = json.loads(line)
        print(json.dumps(entry, indent=2))
        if i == 5:
            break
# Out:
# {
#   "main_category": "All Beauty",
#   "title": "Howard LC0008 Leather Conditioner, 8-Ounce (4-Pack)",
#   "average_rating": 4.8,
#   "rating_number": 10,
#   "features": [],
#   "description": [],
#   "price": null,
#   "images": [
#     {
#       "thumb": "https://m.media-amazon.com/images/I/41qfjSfqNyL._SS40_.jpg",
#       "large": "https://m.media-amazon.com/images/I/41qfjSfqNyL.jpg",
#       "variant": "MAIN",
#       "hi_res": null
#     },
#     {
#       "thumb": "https://m.media-amazon.com/images/I/41w2yznfuZL._SS40_.jpg",
#       "large": "https://m.media-amazon.com/images/I/41w2yznfuZL.jpg",
#       "variant": "PT01",
#       "hi_res": "https://m.media-amazon.com/images/I/71i77AuI9xL._SL1500_.jpg"
#     }
#   ],
#   "videos": [],
#   "store": "Howard Products",
#   "categories": [],
#   "details": {
#     "Package Dimensions": "7.1 x 5.5 x 3 inches; 2.38 Pounds",
#     "UPC": "617390882781"
#   },
#   "parent_asin": "B01CUPMQZE",
#   "bought_together": null
# }
# {
# ...

# %%
# LENGTH OF EACH DATASET
# meta : 112590
# reviews_train : 561704
# reviews_val : 69840
# reviews_test : 69984
